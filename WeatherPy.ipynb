# %% [markdown]
# # WeatherPy

# %% [markdown]
# ## Resources:
#
# #### Requests Library:
#
# HTTP for Humans
# https://requests.kennethreitz.org/en/master/
#
# Quickstart:
# https://requests.kennethreitz.org/en/master/user/quickstart/#make-a-request
#
# try-except blocks
# https://docs.python.org/3.6/tutorial/errors.html

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %% [markdown]
# ### 1) Create Latitude and Longitude Combinations

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-90.000, high=90.000, size=1500)
lat_lngs = zip(lats,lngs)

# %% [markdown]
# #### The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple. If there are 1,500 latitudes and longitudes, there will be 1,500 tuples of paired latitudes and longitudes, where each latitude and longitude in a tuple can be accessed by the index of 0 and 1, respectively.

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %% [markdown]
# ### 2) Next, let's unpack our lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
coordinates [1:10]
# Out:
# [(74.97960365989604, 21.033198299454554),
#  (-27.13546312210527, -71.73618062926812),
#  (-43.23215308282209, -18.739208999931137),
#  (54.42158498370114, 50.44607583956983),
#  (87.5467020996063, -85.88399500115935),
#  (48.961366266625845, 83.42333861421693),
#  (-52.481294378137434, 9.930779980884807),
#  (-53.51578224535162, 73.0640015583891),
#  (64.43976825664748, -35.05421683551541)]

# %% [markdown]
# ### 3) useing the coordinates in lat_lngs tuple find the nearest city using Python's citipy module

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/ali/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 616

# %% [markdown]
# ### 4) create API key with  OpenWeather and save it as config.py file

# %% [markdown]
# #### 539386f8c633e16f4d4484ec5154ac7f API Name: alisakhi ---- saved in config file in World Weather Analysis folder

# %% [markdown]
# ### 5) Reading JavaScript Object Notation (JSON) Format for API data by using requests library

# %%
import requests
from config import weather_api_key

# %%
requests.__version__
# Out:
# '2.25.1'

# %%
# Api call to open weather site for Boston
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
boston_url = url + "&q=" + "Boston"
boston_data = requests.get(boston_url).json()
boston_data
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 300,
#    'main': 'Drizzle',
#    'description': 'light intensity drizzle',
#    'icon': '09d'},
#   {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 64.38,
#   'feels_like': 64.74,
#   'temp_min': 62.17,
#   'temp_max': 66.94,
#   'pressure': 1015,
#   'humidity': 90},
#  'visibility': 8047,
#  'wind': {'speed': 3, 'deg': 59, 'gust': 11.01},
#  'clouds': {'all': 90},
#  'dt': 1627479300,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1627464773,
#   'sunset': 1627517301},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# #### Api call to Open Weather

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# loop through city
for index,city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append ({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date}
                         )
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 1 | oksfjord
# Processing Record 3 of Set 1 | copiapo
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | koshki
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | kurchum
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | souillac
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | ginir
# Processing Record 12 of Set 1 | piacabucu
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | apastovo
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | gobabis
# Processing Record 19 of Set 1 | salalah
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | nyagan
# Processing Record 23 of Set 1 | banda aceh
# Processing Record 24 of Set 1 | libreville
# Processing Record 25 of Set 1 | khairagarh
# Processing Record 26 of Set 1 | yenagoa
# Processing Record 27 of Set 1 | saint-pierre
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | olafsvik
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | dzaoudzi
# Processing Record 36 of Set 1 | koundara
# Processing Record 37 of Set 1 | calbuco
# Processing Record 38 of Set 1 | paragominas
# Processing Record 39 of Set 1 | richards bay
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | renfrew
# Processing Record 44 of Set 1 | necochea
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | port-gentil
# Processing Record 47 of Set 1 | tapaua
# City not found. Skipping...
# Processing Record 48 of Set 1 | sao joao da barra
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | narsaq
# Processing Record 2 of Set 2 | hobyo
# Processing Record 3 of Set 2 | taoudenni
# Processing Record 4 of Set 2 | nantucket
# Processing Record 5 of Set 2 | carutapera
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | kangaatsiaq
# Processing Record 8 of Set 2 | lyaskelya
# Processing Record 9 of Set 2 | tekeli
# Processing Record 10 of Set 2 | codrington
# Processing Record 11 of Set 2 | calatayud
# Processing Record 12 of Set 2 | moose factory
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | gazanjyk
# Processing Record 16 of Set 2 | san cristobal
# Processing Record 17 of Set 2 | tukrah
# Processing Record 18 of Set 2 | rocha
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | garowe
# Processing Record 22 of Set 2 | dekar
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | pavino
# Processing Record 25 of Set 2 | emirdag
# Processing Record 26 of Set 2 | aden
# Processing Record 27 of Set 2 | laguna
# Processing Record 28 of Set 2 | iquique
# Processing Record 29 of Set 2 | cervo
# Processing Record 30 of Set 2 | comodoro rivadavia
# Processing Record 31 of Set 2 | canutama
# Processing Record 32 of Set 2 | bauchi
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 38 of Set 2 | octeville
# Processing Record 39 of Set 2 | firminy
# Processing Record 40 of Set 2 | dubrovka
# Processing Record 41 of Set 2 | roald
# Processing Record 42 of Set 2 | san juan del sur
# Processing Record 43 of Set 2 | minab
# Processing Record 44 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | lucea
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | penzance
# Processing Record 1 of Set 3 | saint-joseph
# Processing Record 2 of Set 3 | contamana
# Processing Record 3 of Set 3 | manaure
# Processing Record 4 of Set 3 | catamarca
# Processing Record 5 of Set 3 | korla
# Processing Record 6 of Set 3 | paamiut
# Processing Record 7 of Set 3 | gambela
# Processing Record 8 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 9 of Set 3 | gwadar
# Processing Record 10 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 3 | lagoa
# Processing Record 12 of Set 3 | hambantota
# Processing Record 13 of Set 3 | kashi
# Processing Record 14 of Set 3 | briancon
# Processing Record 15 of Set 3 | longyearbyen
# Processing Record 16 of Set 3 | macia
# Processing Record 17 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 18 of Set 3 | kruisfontein
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | pervomayskoye
# Processing Record 21 of Set 3 | saint-francois
# Processing Record 22 of Set 3 | goma
# Processing Record 23 of Set 3 | awbari
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | tocopilla
# Processing Record 26 of Set 3 | abu dhabi
# Processing Record 27 of Set 3 | ashtabula
# Processing Record 28 of Set 3 | aguimes
# Processing Record 29 of Set 3 | nuuk
# Processing Record 30 of Set 3 | port blair
# Processing Record 31 of Set 3 | walvis bay
# Processing Record 32 of Set 3 | kisangani
# Processing Record 33 of Set 3 | sayyan
# Processing Record 34 of Set 3 | guinope
# Processing Record 35 of Set 3 | arifwala
# Processing Record 36 of Set 3 | upata
# Processing Record 37 of Set 3 | camana
# Processing Record 38 of Set 3 | kalmunai
# Processing Record 39 of Set 3 | itarema
# Processing Record 40 of Set 3 | beloha
# Processing Record 41 of Set 3 | clarence town
# Processing Record 42 of Set 3 | maymanak
# City not found. Skipping...
# Processing Record 43 of Set 3 | bubaque
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | noyabrsk
# Processing Record 46 of Set 3 | sinazongwe
# Processing Record 47 of Set 3 | maceio
# Processing Record 48 of Set 3 | kalashnikovo
# Processing Record 49 of Set 3 | ostrovnoy
# Processing Record 50 of Set 3 | moissala
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | chastyye
# Processing Record 3 of Set 4 | guarne
# Processing Record 4 of Set 4 | saldanha
# Processing Record 5 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 4 | vardo
# Processing Record 7 of Set 4 | wunstorf
# Processing Record 8 of Set 4 | belmonte
# Processing Record 9 of Set 4 | clyde river
# Processing Record 10 of Set 4 | aksu
# Processing Record 11 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 4 | bednodemyanovsk
# City not found. Skipping...
# Processing Record 13 of Set 4 | guekedou
# City not found. Skipping...
# Processing Record 14 of Set 4 | dalbandin
# Processing Record 15 of Set 4 | sokolo
# Processing Record 16 of Set 4 | fonte boa
# Processing Record 17 of Set 4 | itaituba
# Processing Record 18 of Set 4 | jumla
# Processing Record 19 of Set 4 | loralai
# Processing Record 20 of Set 4 | constitucion
# Processing Record 21 of Set 4 | keflavik
# Processing Record 22 of Set 4 | muscat
# Processing Record 23 of Set 4 | araouane
# Processing Record 24 of Set 4 | sevlievo
# Processing Record 25 of Set 4 | gat
# Processing Record 26 of Set 4 | quatre cocos
# Processing Record 27 of Set 4 | saint-louis
# Processing Record 28 of Set 4 | mus
# Processing Record 29 of Set 4 | ropczyce
# Processing Record 30 of Set 4 | krasnoselkup
# Processing Record 31 of Set 4 | pangnirtung
# Processing Record 32 of Set 4 | kyabe
# Processing Record 33 of Set 4 | mogadishu
# Processing Record 34 of Set 4 | grand-bourg
# Processing Record 35 of Set 4 | kilindoni
# Processing Record 36 of Set 4 | siavonga
# Processing Record 37 of Set 4 | marsh harbour
# Processing Record 38 of Set 4 | havoysund
# Processing Record 39 of Set 4 | nauta
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | savalou
# Processing Record 42 of Set 4 | springbok
# Processing Record 43 of Set 4 | dossor
# Processing Record 44 of Set 4 | oviedo
# Processing Record 45 of Set 4 | dubai
# Processing Record 46 of Set 4 | harlingen
# Processing Record 47 of Set 4 | chazuta
# Processing Record 48 of Set 4 | djambala
# Processing Record 49 of Set 4 | hamilton
# Processing Record 50 of Set 4 | najran
# Processing Record 1 of Set 5 | male
# Processing Record 2 of Set 5 | vila velha
# Processing Record 3 of Set 5 | truro
# Processing Record 4 of Set 5 | oranjemund
# Processing Record 5 of Set 5 | le havre
# Processing Record 6 of Set 5 | cotonou
# Processing Record 7 of Set 5 | sao filipe
# Processing Record 8 of Set 5 | vyshchetarasivka
# Processing Record 9 of Set 5 | santa cruz cabralia
# Processing Record 10 of Set 5 | sakakah
# Processing Record 11 of Set 5 | lima
# Processing Record 12 of Set 5 | alot
# Processing Record 13 of Set 5 | rio grande
# Processing Record 14 of Set 5 | kutahya
# Processing Record 15 of Set 5 | castro
# Processing Record 16 of Set 5 | shache
# Processing Record 17 of Set 5 | uncia
# Processing Record 18 of Set 5 | san jose
# Processing Record 19 of Set 5 | mitsamiouli
# Processing Record 20 of Set 5 | asyut
# Processing Record 21 of Set 5 | puerto berrio
# Processing Record 22 of Set 5 | tarnogskiy gorodok
# Processing Record 23 of Set 5 | cayenne
# Processing Record 24 of Set 5 | safita
# Processing Record 25 of Set 5 | hofn
# Processing Record 26 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 27 of Set 5 | callaway
# Processing Record 28 of Set 5 | adwa
# Processing Record 29 of Set 5 | lilongwe
# Processing Record 30 of Set 5 | barra velha
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | yabrud
# Processing Record 33 of Set 5 | tripoli
# Processing Record 34 of Set 5 | sulechow
# Processing Record 35 of Set 5 | salinas
# Processing Record 36 of Set 5 | emba
# Processing Record 37 of Set 5 | antalaha
# Processing Record 38 of Set 5 | turochak
# Processing Record 39 of Set 5 | barra patuca
# Processing Record 40 of Set 5 | susice
# Processing Record 41 of Set 5 | sylva
# Processing Record 42 of Set 5 | porto walter
# Processing Record 43 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 5 | dakar
# Processing Record 45 of Set 5 | guanica
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | batticaloa
# Processing Record 48 of Set 5 | luderitz
# Processing Record 49 of Set 5 | oranjestad
# Processing Record 50 of Set 5 | goure
# Processing Record 1 of Set 6 | rio gallegos
# Processing Record 2 of Set 6 | sorland
# Processing Record 3 of Set 6 | kudahuvadhoo
# Processing Record 4 of Set 6 | puerto del rosario
# Processing Record 5 of Set 6 | vestmannaeyjar
# Processing Record 6 of Set 6 | mansa
# Processing Record 7 of Set 6 | omboue
# Processing Record 8 of Set 6 | inhambane
# Processing Record 9 of Set 6 | terenos
# Processing Record 10 of Set 6 | mumbwa
# Processing Record 11 of Set 6 | afsin
# Processing Record 12 of Set 6 | leh
# Processing Record 13 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 6 | camacha
# Processing Record 15 of Set 6 | ancud
# Processing Record 16 of Set 6 | novobirilyussy
# Processing Record 17 of Set 6 | black river
# Processing Record 18 of Set 6 | pampierstad
# Processing Record 19 of Set 6 | mehamn
# Processing Record 20 of Set 6 | ankpa
# Processing Record 21 of Set 6 | pangoa
# Processing Record 22 of Set 6 | adrar
# Processing Record 23 of Set 6 | totness
# Processing Record 24 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 25 of Set 6 | caravelas
# Processing Record 26 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 27 of Set 6 | saurimo
# Processing Record 28 of Set 6 | boa vista
# Processing Record 29 of Set 6 | itambe
# Processing Record 30 of Set 6 | nicoya
# Processing Record 31 of Set 6 | berlevag
# Processing Record 32 of Set 6 | medea
# Processing Record 33 of Set 6 | dubti
# Processing Record 34 of Set 6 | kyshtovka
# Processing Record 35 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 6 | nouakchott
# Processing Record 37 of Set 6 | eydhafushi
# Processing Record 38 of Set 6 | bulungu
# Processing Record 39 of Set 6 | sikasso
# Processing Record 40 of Set 6 | santana do livramento
# Processing Record 41 of Set 6 | pangody
# Processing Record 42 of Set 6 | bathsheba
# Processing Record 43 of Set 6 | stege
# Processing Record 44 of Set 6 | sept-iles
# Processing Record 45 of Set 6 | gusau
# Processing Record 46 of Set 6 | sao gabriel
# Processing Record 47 of Set 6 | shumikha
# Processing Record 48 of Set 6 | amargosa
# Processing Record 49 of Set 6 | lebanon
# Processing Record 50 of Set 6 | pytalovo
# Processing Record 1 of Set 7 | grand gaube
# Processing Record 2 of Set 7 | nizwa
# Processing Record 3 of Set 7 | saint anthony
# Processing Record 4 of Set 7 | northallerton
# Processing Record 5 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | morondava
# Processing Record 7 of Set 7 | sisimiut
# Processing Record 8 of Set 7 | padang
# Processing Record 9 of Set 7 | lagos
# Processing Record 10 of Set 7 | arlit
# Processing Record 11 of Set 7 | sudogda
# Processing Record 12 of Set 7 | razole
# Processing Record 13 of Set 7 | chimore
# Processing Record 14 of Set 7 | diego de almagro
# Processing Record 15 of Set 7 | asfi
# Processing Record 16 of Set 7 | jardim
# Processing Record 17 of Set 7 | san agustin
# Processing Record 18 of Set 7 | husavik
# Processing Record 19 of Set 7 | harper
# Processing Record 20 of Set 7 | maneromango
# Processing Record 21 of Set 7 | margate
# Processing Record 22 of Set 7 | thompson
# Processing Record 23 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 7 | riyadh
# Processing Record 25 of Set 7 | straumen
# Processing Record 26 of Set 7 | cabedelo
# Processing Record 27 of Set 7 | eskil
# Processing Record 28 of Set 7 | sinnamary
# Processing Record 29 of Set 7 | marsa matruh
# Processing Record 30 of Set 7 | sabha
# Processing Record 31 of Set 7 | sao raimundo nonato
# Processing Record 32 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 7 | sur
# Processing Record 34 of Set 7 | aripuana
# Processing Record 35 of Set 7 | chapais
# Processing Record 36 of Set 7 | dolores
# Processing Record 37 of Set 7 | ponta delgada
# Processing Record 38 of Set 7 | saint-leu
# Processing Record 39 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 40 of Set 7 | brae
# Processing Record 41 of Set 7 | neuquen
# Processing Record 42 of Set 7 | villarrobledo
# Processing Record 43 of Set 7 | muros
# Processing Record 44 of Set 7 | samsun
# Processing Record 45 of Set 7 | santa cecilia
# Processing Record 46 of Set 7 | iqaluit
# Processing Record 47 of Set 7 | langres
# Processing Record 48 of Set 7 | borovskoy
# Processing Record 49 of Set 7 | ndola
# Processing Record 50 of Set 7 | kalevala
# Processing Record 1 of Set 8 | panormos
# Processing Record 2 of Set 8 | lisakovsk
# Processing Record 3 of Set 8 | nara
# Processing Record 4 of Set 8 | chandbali
# Processing Record 5 of Set 8 | viedma
# Processing Record 6 of Set 8 | faya
# Processing Record 7 of Set 8 | eastlake
# Processing Record 8 of Set 8 | agdas
# Processing Record 9 of Set 8 | borgarnes
# Processing Record 10 of Set 8 | urumqi
# Processing Record 11 of Set 8 | praia
# Processing Record 12 of Set 8 | trelew
# Processing Record 13 of Set 8 | thomaston
# Processing Record 14 of Set 8 | concepcion
# Processing Record 15 of Set 8 | pisco
# Processing Record 16 of Set 8 | carnarvon
# Processing Record 17 of Set 8 | aksarayskiy
# Processing Record 18 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 20 of Set 8 | gauribidanur
# Processing Record 21 of Set 8 | anloga
# Processing Record 22 of Set 8 | grindavik
# Processing Record 23 of Set 8 | hearst
# Processing Record 24 of Set 8 | tulum
# Processing Record 25 of Set 8 | alta
# Processing Record 26 of Set 8 | tabora
# Processing Record 27 of Set 8 | lubango
# Processing Record 28 of Set 8 | goundam
# Processing Record 29 of Set 8 | campos novos
# Processing Record 30 of Set 8 | ureki
# Processing Record 31 of Set 8 | matara
# Processing Record 32 of Set 8 | arys
# Processing Record 33 of Set 8 | santa cruz del sur
# Processing Record 34 of Set 8 | oxapampa
# Processing Record 35 of Set 8 | akhalgori
# Processing Record 36 of Set 8 | paratinga
# Processing Record 37 of Set 8 | touros
# Processing Record 38 of Set 8 | ilheus
# Processing Record 39 of Set 8 | la union
# Processing Record 40 of Set 8 | senador jose porfirio
# Processing Record 41 of Set 8 | florianopolis
# Processing Record 42 of Set 8 | bombay
# Processing Record 43 of Set 8 | bushehr
# Processing Record 44 of Set 8 | kadoma
# Processing Record 45 of Set 8 | mega
# Processing Record 46 of Set 8 | varkaus
# Processing Record 47 of Set 8 | iesolo
# Processing Record 48 of Set 8 | koutsouras
# Processing Record 49 of Set 8 | naryan-mar
# Processing Record 50 of Set 8 | vallenar
# Processing Record 1 of Set 9 | barreiras
# Processing Record 2 of Set 9 | kirkwall
# Processing Record 3 of Set 9 | kortkeros
# Processing Record 4 of Set 9 | marienburg
# Processing Record 5 of Set 9 | ouadda
# Processing Record 6 of Set 9 | talnakh
# Processing Record 7 of Set 9 | el tigre
# Processing Record 8 of Set 9 | buraydah
# Processing Record 9 of Set 9 | porto novo
# Processing Record 10 of Set 9 | kabalo
# Processing Record 11 of Set 9 | rachitoasa
# Processing Record 12 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 9 | san carlos de bariloche
# Processing Record 14 of Set 9 | camapua
# Processing Record 15 of Set 9 | sibiti
# Processing Record 16 of Set 9 | puerto carreno
# Processing Record 17 of Set 9 | tucuma
# Processing Record 18 of Set 9 | zaozerne
# Processing Record 19 of Set 9 | key largo
# Processing Record 20 of Set 9 | tombouctou
# Processing Record 21 of Set 9 | kano
# Processing Record 22 of Set 9 | bonoua
# Processing Record 23 of Set 9 | jundubah
# City not found. Skipping...
# Processing Record 24 of Set 9 | burica
# City not found. Skipping...
# Processing Record 25 of Set 9 | sanaur
# Processing Record 26 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 27 of Set 9 | bafq
# Processing Record 28 of Set 9 | holme
# Processing Record 29 of Set 9 | kollam
# Processing Record 30 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 9 | kozluk
# Processing Record 32 of Set 9 | bunda
# Processing Record 33 of Set 9 | kamenka
# Processing Record 34 of Set 9 | laives
# Processing Record 35 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 9 | ust-tsilma
# Processing Record 37 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 38 of Set 9 | busayra
# Processing Record 39 of Set 9 | negombo
# Processing Record 40 of Set 9 | bodden town
# Processing Record 41 of Set 9 | vestmanna
# Processing Record 42 of Set 9 | ambilobe
# Processing Record 43 of Set 9 | keti bandar
# Processing Record 44 of Set 9 | bristol
# Processing Record 45 of Set 9 | mustafakemalpasa
# Processing Record 46 of Set 9 | menongue
# Processing Record 47 of Set 9 | bikaner
# Processing Record 48 of Set 9 | kuruman
# Processing Record 49 of Set 9 | henties bay
# Processing Record 50 of Set 9 | de land
# Processing Record 1 of Set 10 | kologriv
# Processing Record 2 of Set 10 | privolzhskiy
# Processing Record 3 of Set 10 | zenzeli
# Processing Record 4 of Set 10 | sandwick
# Processing Record 5 of Set 10 | veraval
# Processing Record 6 of Set 10 | dingle
# Processing Record 7 of Set 10 | kisanga
# Processing Record 8 of Set 10 | sancti spiritus
# Processing Record 9 of Set 10 | kaura namoda
# Processing Record 10 of Set 10 | hammerfest
# Processing Record 11 of Set 10 | marawi
# Processing Record 12 of Set 10 | harindanga
# Processing Record 13 of Set 10 | verdalsora
# City not found. Skipping...
# Processing Record 14 of Set 10 | natal
# Processing Record 15 of Set 10 | goderich
# Processing Record 16 of Set 10 | nisia floresta
# Processing Record 17 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 10 | san onofre
# Processing Record 19 of Set 10 | svetlogorsk
# Processing Record 20 of Set 10 | virginia beach
# Processing Record 21 of Set 10 | qasigiannguit
# Processing Record 22 of Set 10 | andenes
# Processing Record 23 of Set 10 | padre bernardo
# Processing Record 24 of Set 10 | rajbiraj
# Processing Record 25 of Set 10 | bud
# Processing Record 26 of Set 10 | rezekne
# Processing Record 27 of Set 10 | kattivakkam
# Processing Record 28 of Set 10 | rairangpur
# Processing Record 29 of Set 10 | grabouw
# Processing Record 30 of Set 10 | castiglione del lago
# Processing Record 31 of Set 10 | cap malheureux
# Processing Record 32 of Set 10 | taltal
# Processing Record 33 of Set 10 | lucapa
# Processing Record 34 of Set 10 | labelle
# Processing Record 35 of Set 10 | stornoway
# Processing Record 36 of Set 10 | sura
# Processing Record 37 of Set 10 | darab
# Processing Record 38 of Set 10 | sirnak
# Processing Record 39 of Set 10 | miraflores
# Processing Record 40 of Set 10 | vagur
# Processing Record 41 of Set 10 | yar-sale
# Processing Record 42 of Set 10 | oistins
# Processing Record 43 of Set 10 | benghazi
# Processing Record 44 of Set 10 | otkaznoye
# Processing Record 45 of Set 10 | urubamba
# Processing Record 46 of Set 10 | kiruna
# Processing Record 47 of Set 10 | alta floresta
# Processing Record 48 of Set 10 | alghero
# Processing Record 49 of Set 10 | kautokeino
# Processing Record 50 of Set 10 | safaga
# Processing Record 1 of Set 11 | san andres
# Processing Record 2 of Set 11 | shatsk
# Processing Record 3 of Set 11 | lodja
# Processing Record 4 of Set 11 | chisinau
# Processing Record 5 of Set 11 | zaltan
# Processing Record 6 of Set 11 | la romana
# Processing Record 7 of Set 11 | mariel
# Processing Record 8 of Set 11 | onhaye
# Processing Record 9 of Set 11 | dudinka
# Processing Record 10 of Set 11 | abnub
# Processing Record 11 of Set 11 | nsanje
# Processing Record 12 of Set 11 | aketi
# Processing Record 13 of Set 11 | mvangue
# Processing Record 14 of Set 11 | shchuchye
# City not found. Skipping...
# Processing Record 15 of Set 11 | dalhousie
# Processing Record 16 of Set 11 | dwarka
# Processing Record 17 of Set 11 | jiwani
# Processing Record 18 of Set 11 | palmas bellas
# Processing Record 19 of Set 11 | lukulu
# Processing Record 20 of Set 11 | winneba
# Processing Record 21 of Set 11 | praia da vitoria
# Processing Record 22 of Set 11 | umm kaddadah
# Processing Record 23 of Set 11 | tiznit
# Processing Record 24 of Set 11 | lakhnadon
# Processing Record 25 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 26 of Set 11 | mahibadhoo
# Processing Record 27 of Set 11 | kuytun
# Processing Record 28 of Set 11 | aanekoski
# Processing Record 29 of Set 11 | sao felix do xingu
# Processing Record 30 of Set 11 | tarrega
# Processing Record 31 of Set 11 | doha
# Processing Record 32 of Set 11 | bridlington
# Processing Record 33 of Set 11 | dadri
# Processing Record 34 of Set 11 | poykovskiy
# Processing Record 35 of Set 11 | olot
# Processing Record 36 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 11 | grootfontein
# Processing Record 38 of Set 11 | moba
# Processing Record 39 of Set 11 | krasnoshchekovo
# Processing Record 40 of Set 11 | bhakkar
# Processing Record 41 of Set 11 | bereda
# Processing Record 42 of Set 11 | bonavista
# Processing Record 43 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 44 of Set 11 | mabaruma
# Processing Record 45 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 11 | canavieiras
# Processing Record 47 of Set 11 | mbini
# Processing Record 48 of Set 11 | sokoto
# Processing Record 49 of Set 11 | coihaique
# Processing Record 50 of Set 11 | harstad
# Processing Record 1 of Set 12 | mahajanga
# Processing Record 2 of Set 12 | kluczbork
# Processing Record 3 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 12 | hillsborough
# Processing Record 5 of Set 12 | campina verde
# Processing Record 6 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 12 | bogovarovo
# Processing Record 8 of Set 12 | westport
# Processing Record 9 of Set 12 | kulhudhuffushi
# Processing Record 10 of Set 12 | rundu
# Processing Record 11 of Set 12 | chernelytsya
# Processing Record 12 of Set 12 | esmeralda
# Processing Record 13 of Set 12 | bundibugyo
# Processing Record 14 of Set 12 | kinshasa
# Processing Record 15 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 16 of Set 12 | mantua
# Processing Record 17 of Set 12 | manali
# Processing Record 18 of Set 12 | khor
# Processing Record 19 of Set 12 | ayorou
# Processing Record 20 of Set 12 | buchanan
# Processing Record 21 of Set 12 | soyo
# Processing Record 22 of Set 12 | embu
# Processing Record 23 of Set 12 | baghdad
# Processing Record 24 of Set 12 | mahon
# Processing Record 25 of Set 12 | koulamoutou
# Processing Record 26 of Set 12 | port ellen
# City not found. Skipping...
# Processing Record 27 of Set 12 | antofagasta
# Processing Record 28 of Set 12 | visnes
# Processing Record 29 of Set 12 | lar
# Processing Record 30 of Set 12 | muisne
# Processing Record 31 of Set 12 | amapa
# Processing Record 32 of Set 12 | puerto baquerizo moreno
# Processing Record 33 of Set 12 | nouadhibou
# Processing Record 34 of Set 12 | cabinda
# Processing Record 35 of Set 12 | tyup
# Processing Record 36 of Set 12 | tabou
# Processing Record 37 of Set 12 | korem
# City not found. Skipping...
# Processing Record 38 of Set 12 | cockburn town
# Processing Record 39 of Set 12 | inirida
# Processing Record 40 of Set 12 | serta
# Processing Record 41 of Set 12 | jutai
# Processing Record 42 of Set 12 | bani walid
# Processing Record 43 of Set 12 | gornopravdinsk
# Processing Record 44 of Set 12 | macusani
# Processing Record 45 of Set 12 | pandaria
# Processing Record 46 of Set 12 | shihezi
# Processing Record 47 of Set 12 | bayonet point
# Processing Record 48 of Set 12 | ubatuba
# Processing Record 49 of Set 12 | semnan
# Processing Record 50 of Set 12 | carmo
# Processing Record 1 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 13 | tambovka
# Processing Record 3 of Set 13 | narodychi
# Processing Record 4 of Set 13 | urengoy
# Processing Record 5 of Set 13 | calama
# Processing Record 6 of Set 13 | bardiyah
# Processing Record 7 of Set 13 | umea
# Processing Record 8 of Set 13 | jalu
# Processing Record 9 of Set 13 | lusambo
# Processing Record 10 of Set 13 | erattupetta
# Processing Record 11 of Set 13 | saint-augustin
# Processing Record 12 of Set 13 | kang
# Processing Record 13 of Set 13 | horasan
# Processing Record 14 of Set 13 | ler
# Processing Record 15 of Set 13 | vagamo
# Processing Record 16 of Set 13 | raudeberg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 565

# %%
# replacing '+' for space will direct to the correct city name in API call
#example
city = 'Cabo San Lucas'
city_url = url + "&q=" + city.replace(" ","+")
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=539386f8c633e16f4d4484ec5154ac7f&q=Cabo+San+Lucas

# %%
# enumerate method
print(list(enumerate(cities[0:10]))) # tuples of cities with index and name
# Out:
# [(0, 'marcona'), (1, 'oksfjord'), (2, 'copiapo'), (3, 'jamestown'), (4, 'koshki'), (5, 'qaanaaq'), (6, 'kurchum'), (7, 'hermanus'), (8, 'souillac'), (9, 'tasiilaq')]

# %% [markdown]
# ### 6) create dataframe of city Data

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Oksfjord  70.2396  22.3479     55.47        77          52        7.18
# 1    Copiapo -27.3667 -70.3333     65.88        20           0        0.74
# 2  Jamestown  42.0970 -79.2353     74.17        82           7        5.99
# 3     Koshki  54.2091  50.4677     74.16        30           3       11.95
# 4    Qaanaaq  77.4840 -69.3632     44.62        98         100        9.26
# 5    Kurchum  48.5722  83.6542     70.34        34           0       14.74
# 6   Hermanus -34.4187  19.2345     58.89        63          54       16.82
# 7   Souillac -20.5167  57.5167     72.36        86         100       22.68
# 8   Tasiilaq  65.6145 -37.6368     50.16        66          91        1.77
# 9      Ginir   7.1333  40.7000     62.24        63         100       13.24
#
#   Country                 Date
# 0      NO  2021-07-28 14:00:21
# 1      CL  2021-07-28 14:00:21
# 2      US  2021-07-28 14:00:22
# 3      RU  2021-07-28 14:00:23
# 4      GL  2021-07-28 14:00:24
# 5      KZ  2021-07-28 14:00:25
# 6      ZA  2021-07-28 14:00:25
# 7      MU  2021-07-28 14:00:26
# 8      GL  2021-07-28 14:00:27
# 9      ET  2021-07-28 14:00:27

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
